# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# dong_df 불러오기

with open("dong_df.csv", 'r', encoding='utf-8') as f:
  file_data = f.readlines()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-ca9546864e85> in <module>
#       1 # dong_df 불러오기
#       2
# ----> 3 with open("dong_df.csv", 'r', encoding='utf-8') as f:
#       4   file_data = f.readlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dong_df.csv'

# %%
# dong_df의 종성이 자음인지 모음인지 판별
