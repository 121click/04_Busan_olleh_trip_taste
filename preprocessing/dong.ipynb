# %%
# dong_df.csv 불러오기

with open("I:\내 드라이브\Code\dong_df.csv", 'r', encoding='utf-8') as f:
  file_data = f.readlines()

# %%
file_data
# Out:
# ['name,jamo\n',
#  '가덕,T\n',
#  '가락,T\n',
#  '가야,F\n',
#  '감만,T\n',
#  '감전,T\n',
#  '감천,T\n',
#  '강동,T\n',
#  '개금,T\n',
#  '거제,F\n',
#  '광복,T\n',
#  '광안,T\n',
#  '괘법,T\n',
#  '괴정,T\n',
#  '구서,F\n',
#  '구평,T\n',
#  '구포,F\n',
#  '금곡,T\n',
#  '금사회동,T\n',
#  '금성,T\n',
#  '기장,T\n',
#  '남부민,T\n',
#  '남산,T\n',
#  '남천,T\n',
#  '남포,T\n',
#  '남항,T\n',
#  '녹산,T\n',
#  '다대,F\n',
#  '당감,T\n',
#  '당감,T\n',
#  '당리,F\n',
#  '대연,T\n',
#  '대저,F\n',
#  '대청,T\n',
#  '덕천,T\n',
#  '덕포,F\n',
#  '동광,T\n',
#  '동대신,T\n',
#  '동삼,T\n',
#  '만덕,T\n',
#  '망미,F\n',
#  '명륜,T\n',
#  '명장,T\n',
#  '명지,F\n',
#  '모라,F\n',
#  '문현,T\n',
#  '민락,T\n',
#  '반송,T\n',
#  '반여,F\n',
#  '범일,T\n',
#  '범천,T\n',
#  '보수,F\n',
#  '복산,T\n',
#  '봉래,T\n',
#  '부곡,T\n',
#  '부민,T\n',
#  '부암,T\n',
#  '부전,T\n',
#  '부평,T\n',
#  '사직,T\n',
#  '삼락,T\n',
#  '서면,T\n',
#  '서대신,T\n',
#  '선두구,F\n',
#  '송정,T\n',
#  '수민,T\n',
#  '수영,T\n',
#  '수정,T\n',
#  '신선,T\n',
#  '신평,T\n',
#  '아미,F\n',
#  '안락,T\n',
#  '암남,T\n',
#  '양정,T\n',
#  '엄궁,T\n',
#  '연산,T\n',
#  '연지,F\n',
#  '영선,T\n',
#  '영주,T\n',
#  '온천,T\n',
#  '용당,T\n',
#  '용호,F\n',
#  '우동,T\n',
#  '우암,T\n',
#  '일광,T\n',
#  '장림,T\n',
#  '장안,T\n',
#  '장전,T\n',
#  '재송,T\n',
#  '전포,F\n',
#  '정관,T\n',
#  '좌동,T\n',
#  '좌천,T\n',
#  '주례,F\n',
#  '중동,T\n',
#  '중앙,T\n',
#  '철마,F\n',
#  '노포,F\n',
#  '청학,T\n',
#  '초읍,T\n',
#  '초량,T\n',
#  '초장,T\n',
#  '충무,F\n',
#  '하단,T\n',
#  '학장,T\n',
#  '화명,T\n']

# %%
import pandas as pd

df = pd.read_csv("I:\내 드라이브\Code\dong_df.csv", 'r', encoding='utf-8')
df
# Out:
#     name,jamo
# 0        가덕,T
# 1        가락,T
# 2        가야,F
# 3        감만,T
# 4        감전,T
# ..        ...
# 100      초장,T
# 101      충무,F
# 102      하단,T
# 103      학장,T
# 104      화명,T
#
# [105 rows x 1 columns]

# %%
from jamo import h2j, j2hcj


# def get_jongsung_TF(df):
#     sample_text_list = list(df)
#     last_word = sample_text_list[-1]
#     last_word_jamo_list = list(j2hcj(h2j(last_word)))
#     last_jamo = last_word_jamo_list[-1]

#     jongsung_TF = "T"

#     if last_jamo in ['ㅏ', 'ㅑ', 'ㅓ', 'ㅕ', 'ㅗ', 'ㅛ', 'ㅜ', 'ㅠ', 'ㅡ', 'ㅣ', 'ㅘ', 'ㅚ', 'ㅙ', 'ㅝ', 'ㅞ', 'ㅢ', 'ㅐ,ㅔ', 'ㅟ', 'ㅖ', 'ㅒ']:
#         jongsung_TF = "F"

#     return jongsung_TF
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# i:\내 드라이브\Code\현국\dong.ipynb 셀 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/i%3A/%EB%82%B4%20%EB%93%9C%EB%9D%BC%EC%9D%B4%EB%B8%8C/Code/%ED%98%84%EA%B5%AD/dong.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> from jamo import h2j, j2hcj
#
# ModuleNotFoundError: No module named 'jamo'

# %%
# pandas 불러오기

# %%
#
