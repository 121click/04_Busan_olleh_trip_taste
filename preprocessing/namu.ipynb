# %%
# pandas 불러오기

import pandas as pd

# %%
# 데이터 불러오기

df = pd.read_csv('./dong_name.csv')
df
# Out:
#       name
# 0     가덕도동
# 1      가락동
# 2     가야2동
# 3    가야제1동
# 4     감만1동
# ..     ...
# 200   하단2동
# 201    학장동
# 202   화명1동
# 203   화명2동
# 204   화명3동
#
# [205 rows x 1 columns]

# %%
keyword = df['name'].unique()
keyword
# Out:
# array(['가덕도동', '가락동', '가야2동', '가야제1동', '감만1동', '감만2동', '감전동', '감천1동',
#        '감천2동', '강동동', '개금1동', '개금2동', '개금3동', '거제1동', '거제2동', '거제3동',
#        '거제4동', '광복동', '광안1동', '광안2동', '광안3동', '광안4동', '괘법동', '괴정1동',
#        '괴정2동', '괴정3동', '괴정4동', '구서1동', '구서2동', '구평동', '구포1동', '구포2동',
#        '구포3동', '금곡동', '금사회동동', '금성동', '기장읍', '남부민1동', '남부민2동', '남산동',
#        '남천1동', '남천2동', '남포동', '남항동', '녹산동', '다대1동', '다대2동', '당감2동',
#        '당감4동', '당감제1동', '당리동', '대연1동', '대연3동', '대연4동', '대연5동', '대연6동',
#        '대저1동', '대저2동', '대청동', '덕천1동', '덕천2동', '덕천3동', '덕포1동', '덕포2동',
#        '동광동', '동대신1동', '동대신2동', '동대신3동', '동삼1동', '동삼2동', '동삼3동', '만덕1동',
#        '만덕2동', '만덕3동', '망미1동', '망미2동', '명륜동', '명장1동', '명장2동', '명지1동',
#        '명지2동', '모라1동', '모라3동', '문현1동', '문현2동', '문현3동', '문현4동', '민락동',
#        '반송1동', '반송2동', '반여1동', '반여2동', '반여3동', '반여4동', '범일1동', '범일2동',
#        '범일5동', '범천1동', '범천2동', '보수동', '복산동', '봉래1동', '봉래2동', '부곡1동',
# ...

# %%
# df의 name에서 마지막 글자 제거

df['name'] = df['name'].str.rstrip('동')
df
# Out:
#      name
# 0     가덕도
# 1      가락
# 2     가야2
# 3    가야제1
# 4     감만1
# ..    ...
# 200   하단2
# 201    학장
# 202   화명1
# 203   화명2
# 204   화명3
#
# [205 rows x 1 columns]

# %%
df['name'] = df['name'].str.replace('읍', '')
df
# Out:
#      name
# 0     가덕도
# 1      가락
# 2     가야2
# 3    가야제1
# 4     감만1
# ..    ...
# 200   하단2
# 201    학장
# 202   화명1
# 203   화명2
# 204   화명3
#
# [205 rows x 1 columns]

# %%
df['name'] = df['name'].str.replace('면', '')
df
# Out:
#      name
# 0     가덕도
# 1      가락
# 2     가야2
# 3    가야제1
# 4     감만1
# ..    ...
# 200   하단2
# 201    학장
# 202   화명1
# 203   화명2
# 204   화명3
#
# [205 rows x 1 columns]

# %%
df['name'] = df['name'].str.replace('도', '')
df
# Out:
#      name
# 0      가덕
# 1      가락
# 2     가야2
# 3    가야제1
# 4     감만1
# ..    ...
# 200   하단2
# 201    학장
# 202   화명1
# 203   화명2
# 204   화명3
#
# [205 rows x 1 columns]

# %%
df['name'] = df['name'].str.replace('가야제', '가야')
df
# Out:
#     name
# 0     가덕
# 1     가락
# 2    가야2
# 3    가야1
# 4    감만1
# ..   ...
# 200  하단2
# 201   학장
# 202  화명1
# 203  화명2
# 204  화명3
#
# [205 rows x 1 columns]

# %%
# 숫자 제거

df['name'] = df['name'].str.replace(r'[0-9]', '')
df
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_672\4265348718.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['name'] = df['name'].str.replace(r'[0-9]', '')
#     name
# 0     가덕
# 1     가락
# 2     가야
# 3     가야
# 4     감만
# ..   ...
# 200   하단
# 201   학장
# 202   화명
# 203   화명
# 204   화명
#
# [205 rows x 1 columns]

# %%
df.drop
# Out:
# <bound method DataFrame.drop of     name
# 0     가덕
# 1     가락
# 2     가야
# 3     가야
# 4     감만
# ..   ...
# 200   하단
# 201   학장
# 202   화명
# 203   화명
# 204   화명
#
# [205 rows x 1 columns]>

# %%
df_keyword = df.groupby(['name']).sum()
df_keyword
# Out:
# Empty DataFrame
# Columns: []
# Index: [가덕, 가락, 가야, 감만, 감전, 감천, 강, 개금, 거제, 광복, 광안, 괘법, 괴정, 구서, 구평, 구포, 금곡, 금사회, 금성, 기장, 남부민, 남산, 남천, 남포, 남항, 녹산, 다대, 당감, 당감제, 당리, 대연, 대저, 대청, 덕천, 덕포, 동광, 동대신, 동삼, 만덕, 망미, 명륜, 명장, 명지, 모라, 문현, 민락, 반송, 반여, 범일, 범천, 보수, 복산, 봉래, 부곡, 부민, 부암, 부전, 부평, 사직, 삼락, 서, 서대신, 선두구, 송정, 수민, 수영, 수정, 신선, 신평, 아미, 안락, 암남, 양정, 엄궁, 연산, 연지, 영선, 영주, 온천, 용당, 용호, 우, 우암, 일광, 장림, 장안, 장전, 재송, 전포, 정관, 좌, 좌천, 주례, 중, 중앙, 철마, 청룡노포, 청학, 초, 초량, ...]
#
# [105 rows x 0 columns]

# %%
df_keyword.to_csv('./dong_df.csv', index = None)

# %%
keyword1 = df['name'].unique()
keyword1
# Out:
# array(['가덕', '가락', '가야', '감만', '감전', '감천', '강', '개금', '거제', '광복', '광안',
#        '괘법', '괴정', '구서', '구평', '구포', '금곡', '금사회', '금성', '기장', '남부민', '남산',
#        '남천', '남포', '남항', '녹산', '다대', '당감', '당감제', '당리', '대연', '대저', '대청',
#        '덕천', '덕포', '동광', '동대신', '동삼', '만덕', '망미', '명륜', '명장', '명지', '모라',
#        '문현', '민락', '반송', '반여', '범일', '범천', '보수', '복산', '봉래', '부곡', '부민',
#        '부암', '부전', '부평', '사직', '삼락', '서', '서대신', '선두구', '송정', '수민', '수영',
#        '수정', '신선', '신평', '아미', '안락', '암남', '양정', '엄궁', '연산', '연지', '영선',
#        '영주', '온천', '용당', '용호', '우', '우암', '일광', '장림', '장안', '장전', '재송',
#        '전포', '정관', '좌', '좌천', '주례', '중', '중앙', '철마', '청룡노포', '청학', '초량',
#        '초', '초장', '충무', '하단', '학장', '화명'], dtype=object)

# %%
# keyword1을 list 형태로 변환

# %%
# keyword1의 초성 종성을 판별

from jamo import h2j, j2hcj

# %%
def get_jongsung_TF(sample_text):
    sample_text_list = list(sample_text)
    last_word = sample_text_list[-1]
    last_word_jamo_list = list(j2hcj(h2j(last_word)))
    last_jamo = last_word_jamo_list[-1]

    jongsung_TF = "T"

    if last_jamo in ['ㅏ', 'ㅑ', 'ㅓ', 'ㅕ', 'ㅗ', 'ㅛ', 'ㅜ', 'ㅠ', 'ㅡ', 'ㅣ', 'ㅘ', 'ㅚ', 'ㅙ', 'ㅝ', 'ㅞ', 'ㅢ', 'ㅐ,ㅔ', 'ㅟ', 'ㅖ', 'ㅒ']:
        jongsung_TF = "F"

    return jongsung_TF
