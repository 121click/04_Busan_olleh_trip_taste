# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Data/blog_content_final.csv', encoding='utf-8')

# df 글자수세기

print(df['content'].str.len())
# Out:
# 0      59807
# 1      23015
# 2      85218
# 3      68161
# 4      73094
#        ...
# 561    88356
# 562    79083
# 563    73998
# 564    90063
# 565    65268
# Name: content, Length: 566, dtype: int64

# %%
df['content'].str.len().sum()
# Out:
# 196687934
