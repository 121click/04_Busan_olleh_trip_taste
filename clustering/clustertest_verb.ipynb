# %% [markdown]
# # 최 하단부 plt에 한국어 표시하기 위한 부분

# %%
# 단계 1: 폰트 설치

# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 5 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 1s (15.7 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
# 단계 2: 런타임 재시작
import os
os.kill(os.getpid(), 9)

# %%
# 단계 3: 한글 폰트 설정
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm

# 마이너스 표시 문제
mpl.rcParams['axes.unicode_minus'] = False
	
# 폰트 적용
plt.rc('font', family='NanumBarunGothic')

# %%
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 시작

# %%
# 데이터 불러오기

df_mecab_verb = pd.read_csv('/content/drive/MyDrive/Data/df_mecab_verb.csv', encoding='utf-8')

df_mecab_verb.head()
# Out:
#    Unnamed: 0        keyword  \
# 0           0          168계단
# 1           1          25의용단
# 2           2       40계단 문화관
# 3           3  40계단 문화관광테마거리
# 4           4     60년전통 할매국밥
#
#                                           mecab_verb
# 0  ['풀', '되', '가', '가', '잡', '하', '오', '하', '대', ...
# 1  ['가', '살아나', '살', '살리', '받', '하', '띄', '보이', '...
# 2  ['즐기', '하', '해내', '하', '되', '나누', '되', '몰', '들...
# 3  ['불리', '하', '가', '하', '오', '사', '알리', '있', '붙'...
# 4  ['먹', '있', '가', '하', '타', '타', '건너', '보', '알',...

# %%
df_mecab_verb['mecab_verb'] = df_mecab_verb['mecab_verb'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 ]', '')

df_mecab_verb.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
#    Unnamed: 0        keyword  \
# 0           0          168계단
# 1           1          25의용단
# 2           2       40계단 문화관
# 3           3  40계단 문화관광테마거리
# 4           4     60년전통 할매국밥
#
#                                           mecab_verb
# 0  풀 되 가 가 잡 하 오 하 대 보 오 하 있 내 내려가 잡 내려가 있 하 내려오 ...
# 1  가 살아나 살 살리 받 하 띄 보이 보 있 처하 버리 되 기리 걸어가 있 걷 찾아가...
# 2  즐기 하 해내 하 되 나누 되 몰 들어가 먹 있 다리 지 몰려드 찾 넘쳐나 오 올라...
# 3  불리 하 가 하 오 사 알리 있 붙 파 불 되 보 넘치 보 있 있 넘 앉 먹 있 넣...
# 4  먹 있 가 하 타 타 건너 보 알 기다리 하 죽 받 오 쓰 먹 먹 들 다니 있 받 ...

# %%
# df_mecab_verb['mecab_verb'].isnull().sum()

# df_mecab_verb['mecab_verb'].value_counts()

# df_mecab_verb['mecab_verb'].value_counts().sum()
# Out:
# 0

# %%
# konlpy 설치

# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 19.4 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 465 kB 63.6 MB/s
# ...

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
# df_mecab_verb의 mecab_adj를 벡터화

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(df_mecab_verb['mecab_verb'])

tfidf_matrix.shape
# Out:
# (566, 3900)

# %% [markdown]
# # K-Means

# %%
# df_mecab_verb의 mecab_adj를 클러스터링

from sklearn.cluster import KMeans

import numpy as np

kmeans = KMeans(n_clusters=5).fit(tfidf_matrix)

kmeans.labels_
# Out:
# array([0, 3, 4, 0, 2, 0, 4, 4, 4, 4, 4, 0, 0, 3, 0, 0, 0, 0, 4, 0, 3, 4,
#        0, 0, 2, 2, 4, 2, 4, 2, 0, 4, 1, 3, 0, 0, 1, 1, 3, 4, 4, 0, 0, 3,
#        3, 1, 3, 4, 1, 3, 1, 4, 1, 3, 0, 4, 4, 2, 0, 1, 4, 0, 1, 3, 4, 4,
#        4, 4, 2, 2, 1, 0, 0, 2, 3, 1, 3, 3, 1, 1, 3, 0, 4, 0, 1, 3, 4, 0,
#        0, 4, 4, 4, 4, 2, 2, 2, 4, 0, 4, 4, 2, 4, 4, 4, 4, 0, 4, 4, 4, 4,
#        2, 4, 3, 3, 3, 0, 4, 4, 3, 2, 3, 4, 4, 4, 1, 3, 2, 1, 0, 2, 1, 2,
#        2, 0, 2, 2, 3, 2, 4, 4, 2, 4, 3, 0, 1, 4, 3, 1, 4, 2, 4, 4, 2, 3,
#        0, 2, 4, 4, 3, 2, 4, 4, 4, 4, 4, 2, 2, 2, 2, 4, 0, 3, 2, 2, 2, 0,
#        1, 0, 3, 4, 1, 4, 4, 4, 1, 2, 0, 1, 4, 0, 4, 1, 2, 0, 4, 4, 4, 4,
#        4, 1, 1, 2, 0, 3, 4, 0, 1, 4, 4, 1, 4, 1, 4, 4, 1, 1, 1, 4, 4, 1,
#        0, 0, 4, 3, 4, 4, 2, 0, 1, 4, 1, 1, 4, 4, 4, 4, 4, 4, 0, 1, 1, 0,
#        4, 4, 4, 1, 1, 1, 1, 4, 4, 0, 3, 3, 1, 1, 1, 0, 1, 0, 0, 1, 1, 1,
#        4, 2, 4, 1, 4, 4, 0, 4, 3, 3, 0, 0, 0, 1, 1, 1, 3, 4, 1, 4, 2, 4,
# ...

# %%
# 위 결과를 시각화

import matplotlib.pyplot as plt

from sklearn.decomposition import PCA

pca = PCA(n_components=2)

pca.fit(tfidf_matrix.toarray())

pca_data = pca.transform(tfidf_matrix.toarray())

plt.scatter(pca_data[:, 0], pca_data[:, 1], c=kmeans.labels_, alpha=0.5)

plt.show()

# %%
# 클러스터링 결과를 df_mecab_verb에 추가

df_mecab_verb['cluster'] = kmeans.labels_
df_mecab_verb.head()
# Out:
#    Unnamed: 0        keyword  \
# 0           0          168계단
# 1           1          25의용단
# 2           2       40계단 문화관
# 3           3  40계단 문화관광테마거리
# 4           4     60년전통 할매국밥
#
#                                            mecab_adj  cluster_M  cluster
# 0  있 없 있 없 비싸 멀 있 많 있 있 있 있 많 많 무섭 힘들 좋 있 많 다르 귀엽...          1        1
# 1  좋 없 없 없 없 같 있 있 어렵 있 좋 같 있 좋 크 굵 노랗 좋 많 없 귀하 많...          4        0
# 2  늦 좋 좋 없 같 비싸 좋 크 크 있 없 없 있 이쁘 좋 있 없 나쁘 없 좋 어이없...          1        1
# 3  수많 있 없 없 없 있 깊 있 있 좋 멋지 있 없 있 있 있 많 많 수많 같 없 같...          1        1
# 4  맛있 없 싫 없 맛있 좋 맛있 아쉬우 무겁 없 맛있 재밌 맛있 없 아쉽 덥 맛있 있...          3        4

# %%
# 클러스터의 키워드 분류

df_mecab_verb['cluster'].value_counts()
# Out:
# 2    190
# 1    164
# 0    109
# 4     57
# 3     46
# Name: cluster, dtype: int64

# %%
# cluster가 2인 keyword 행의 수 출력

df_mecab_verb[df_mecab_verb['cluster'] == 2].shape
# Out:
# (190, 4)

# %%
# cluster column을 기준으로 groupby

df_groupby_cluster = df_mecab_verb.groupby('cluster').count()
df_groupby_cluster
# Out:
#          Unnamed: 0  keyword  mecab_adj
# cluster
# 0               109      109        109
# 1               164      164        164
# 2               190      190        190
# 3                46       46         46
# 4                57       57         57

# %%
# df_mecab_verb에서 cluster가 2인 keyword를 df_cluster_2에 저장

df_cluster_2 = df_mecab_verb[df_mecab_verb['cluster'] == 2]
df_cluster_2
# Out:
#      Unnamed: 0   keyword                                          mecab_adj  \
# 0             0     168계단  있 없 있 없 비싸 멀 있 많 있 있 있 있 많 많 무섭 힘들 좋 있 많 다르 귀엽...
# 2             2  40계단 문화관  늦 좋 좋 없 같 비싸 좋 크 크 있 없 없 있 이쁘 좋 있 없 나쁘 없 좋 어이없...
# 5             5      75광장  재밌 좋 없 길 좋 맑 낫 있 괜찮 얕 세 높 괜찮 많 좋 맑 같 괜찮 강하 자리 ...
# 6             6     AREA6  짧 알차 넓 있 없 힘들 젊 그렇 짧 좋 늦 엄청나 있 있 같 낮 많 좁 많 많 없...
# 8             8     F1963  예쁘 있 많 있 있 좋 있 같 있 같 있 있 있 좋 많 재미있 좋 없 없 없 좋 넓...
# ..          ...       ...                                                ...
# 558         558       몰운대  좋 같 있 많 같 깊 같 빠르 좋 없 좋 좋 좋 없 맛있 좋 좋 좋 같 맛있 얇 맛...
# 560         560      송도반도  같 많 멋지 있 짧 없 멋지 높 가깝 같 많 환하 멋지 싱그럽 좋 있 없 같 무섭 ...
# 561         561       오륙도  괜찮 춥 빠르 좋 있 넓디 넓 있 없 무섭 없 밝 춥 빠르 춥 길 아쉽 괜찮 좋 힘...
# 562         562       이기대  넓 같 있 좋 작 같 좋 좋 좋 예쁘 맛있 좋 춥 덥 멋있 좋 같 편하 좋 좋 좋 ...
# 564         564       태종대  없 같 좋 같 길 있 같 좋 빠르 있 있 좋 좋 작 많 많 놀랍 그렇 많 그렇 뒤늦...
#
#      cluster
# 0          2
# 2          2
# ...

# %%
# df_cluster_2의 keyword를 리스트 형태로 출력

df_cluster_2['keyword'].tolist()

# %%
# df_cluster_2 Unnamed: 0 컬럼 삭제한 뒤 csv로 저장

df_cluster_2 = df_cluster_2.drop(['Unnamed: 0'], axis=1)
df_cluster_2.to_csv('df_cluster_2.csv')

# %%
# df_mecab_verb에서 cluster가 4인 keyword를 df_cluster_2에 저장

df_cluster_4 = df_mecab_verb[df_mecab_verb['cluster'] == 4]
df_cluster_4
# Out:
#      Unnamed: 0                  keyword  \
# 10           10         SEA LIFE 부산아쿠아리움
# 20           20                   감만시민공원
# 36           36             광안리 SUP Zone
# 37           37                  광안리어방축제
# 38           38                  광안리패들보드
# 48           48                  국립부산과학관
# 51           51                  국립해양박물관
# 74           74                낙동강 생태탐방선
# 75           75                낙동강구포나루축제
# 80           80  남도해양관광열차 S-트레인(S-train)
# 124         124                동래읍성 역사축제
# 178         178                  법륜사(부산)
# 184         184                복천박물관(부산)
# 207         207               부산 트릭아이뮤지엄
# 217         217                부산국제록페스티벌
# 221         221                부산다이아몬드타워
# 225         225                   부산롯데월드
# 229         229                    부산박물관
# 231         231                   부산비엔날레
# 232         232                  부산세관박물관
# 236         236                  부산아쿠아리움
# 238         238         부산어린이워터파크_키득키득파크
# ...

# %%
# df_cluster_4의 keyword를 리스트 형태로 출력

df_cluster_4['keyword'].tolist()
# Out:
# ['SEA LIFE 부산아쿠아리움',
#  '감만시민공원',
#  '광안리 SUP Zone',
#  '광안리어방축제',
#  '광안리패들보드',
#  '국립부산과학관',
#  '국립해양박물관',
#  '낙동강 생태탐방선',
#  '낙동강구포나루축제',
#  '남도해양관광열차 S-트레인(S-train)',
#  '동래읍성 역사축제',
#  '법륜사(부산)',
#  '복천박물관(부산)',
#  '부산 트릭아이뮤지엄',
#  '부산국제록페스티벌',
#  '부산다이아몬드타워',
#  '부산롯데월드',
#  '부산박물관',
#  '부산비엔날레',
#  '부산세관박물관',
#  '부산아쿠아리움',
#  '부산어린이워터파크_키득키득파크',
#  '부산어촌민속관',
#  '부산원도심골목길축제',
#  '부산원아시아페스티벌(BOF)',
#  '부산자연곤충마을',
#  '부산키자니아',
#  '부산태권도체험',
#  '부산해양자연사박물관',
#  '부산해양치유프로그램(광안리)',
#  '브릭캠퍼스 부산',
#  '삼락수상레포츠타운',
#  '소두방공원',
#  '송정서핑학교',
#  '수미르공원',
#  '수산과학관(부산)',
#  '수영강상설카약체험',
#  '스카이라인 루지(부산)',
#  '스포원파크',
#  '아미르공원',
#  '역사의 디오라마',
#  '영도관광사격장',
#  '영도다리축제',
#  '임시수도기념관',
#  '재난안전체험관',
#  '정관생태하천학습문화축제',
#  '조선통신사역사관',
#  '조선통신사축제',
#  '차성문화제',
#  '초원숲속캠핑장',
#  '키자니아 부산',
#  '킴스아트필드미술관',
#  '태종대스쿠버다이빙',
#  '한국신발관',
#  '해양스포츠교실',
#  '현대모터스튜디오 부산',
#  '화명수상레포츠타운']

# %% [markdown]
# # K - Medroids Clustering

# %%
! pip install scikit-learn-extra
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.7 MB 5.2 MB/s
# ...

# %%
# 위 df_mecab_verb의 mecab_adj를 KMedoids로 클러스터링

from sklearn_extra.cluster import KMedoids

kmedoids = KMedoids(n_clusters=5, random_state=0).fit(tfidf_matrix)

kmedoids.labels_
# Out:
# array([1, 3, 3, 3, 0, 1, 3, 2, 0, 0, 0, 3, 2, 3, 2, 1, 1, 3, 3, 2, 1, 0,
#        2, 3, 0, 0, 4, 0, 0, 0, 2, 4, 3, 3, 1, 2, 3, 3, 4, 4, 4, 1, 2, 3,
#        3, 3, 0, 2, 3, 3, 3, 2, 3, 3, 1, 2, 2, 0, 1, 3, 0, 1, 3, 3, 4, 4,
#        4, 4, 0, 4, 3, 1, 3, 0, 3, 3, 3, 3, 4, 3, 3, 3, 4, 2, 3, 1, 0, 2,
#        3, 4, 3, 0, 4, 0, 0, 0, 4, 1, 1, 1, 0, 0, 4, 2, 0, 1, 2, 3, 4, 3,
#        0, 0, 3, 3, 3, 3, 4, 0, 3, 0, 3, 4, 4, 2, 3, 1, 0, 3, 1, 0, 3, 0,
#        0, 1, 0, 0, 0, 0, 4, 4, 4, 0, 3, 1, 3, 3, 3, 4, 2, 0, 0, 0, 4, 2,
#        1, 0, 3, 0, 2, 0, 4, 1, 4, 4, 4, 0, 0, 0, 0, 2, 3, 3, 0, 0, 0, 1,
#        3, 1, 0, 0, 3, 4, 0, 2, 3, 0, 1, 3, 4, 1, 2, 3, 4, 1, 2, 4, 4, 1,
#        0, 3, 3, 0, 2, 3, 4, 2, 3, 2, 3, 3, 3, 3, 4, 4, 3, 3, 3, 0, 0, 3,
#        1, 1, 1, 0, 0, 0, 0, 2, 4, 2, 1, 3, 3, 0, 3, 1, 0, 2, 2, 3, 3, 1,
#        2, 3, 4, 3, 3, 4, 3, 3, 2, 2, 3, 3, 0, 3, 4, 1, 3, 1, 2, 4, 3, 3,
#        3, 0, 2, 3, 0, 4, 3, 4, 4, 2, 3, 1, 1, 3, 3, 3, 3, 4, 3, 0, 0, 3,
# ...

# %%
# 위 결과를 시각화

import matplotlib.pyplot as plt

from sklearn.decomposition import PCA

pca = PCA(n_components=2)

pca.fit(tfidf_matrix.toarray())

pca_data = pca.transform(tfidf_matrix.toarray())

plt.scatter(pca_data[:, 0], pca_data[:, 1], c=kmedoids.labels_, alpha=0.5)

plt.show()

# %%
# 클러스터링 결과를 df_mecab_verb에 추가

df_mecab_verb['cluster_M'] = kmedoids.labels_
df_mecab_verb.head()
# Out:
#    Unnamed: 0        keyword  \
# 0           0          168계단
# 1           1          25의용단
# 2           2       40계단 문화관
# 3           3  40계단 문화관광테마거리
# 4           4     60년전통 할매국밥
#
#                                            mecab_adj  cluster_M
# 0  있 없 있 없 비싸 멀 있 많 있 있 있 있 많 많 무섭 힘들 좋 있 많 다르 귀엽...          1
# 1  좋 없 없 없 없 같 있 있 어렵 있 좋 같 있 좋 크 굵 노랗 좋 많 없 귀하 많...          4
# 2  늦 좋 좋 없 같 비싸 좋 크 크 있 없 없 있 이쁘 좋 있 없 나쁘 없 좋 어이없...          1
# 3  수많 있 없 없 없 있 깊 있 있 좋 멋지 있 없 있 있 있 많 많 수많 같 없 같...          1
# 4  맛있 없 싫 없 맛있 좋 맛있 아쉬우 무겁 없 맛있 재밌 맛있 없 아쉽 덥 맛있 있...          3

# %%
# keyword, cluster, cluster_M를 df_mecab_verb_cluster_result에 저장

df_mecab_verb_cluster_result = df_mecab_verb[['keyword', 'cluster', 'cluster_M']]

# df_mecab_verb_cluster_result를 csv로 저장

df_mecab_verb_cluster_result.to_csv('df_mecab_verb_cluster_result.csv')

# %%
# df_mecab_verb_cluster_result를 excel에서 열 수 있게 저장

df_mecab_verb_cluster_result.to_excel('df_mecab_verb_cluster_result.xlsx')

# %%
# keyword 중 cluster와 cluster_M 이 다른 것을 출력

df_mecab_verb_cluster_result[df_mecab_verb_cluster_result['cluster'] != df_mecab_verb_cluster_result['cluster_M']]
# Out:
#           keyword  cluster  cluster_M
# 1           25의용단        0          4
# 4      60년전통 할매국밥        4          3
# 6           AREA6        1          0
# 7         BIFF 광장        4          3
# 9    KT&G 상상마당 부산        1          2
# ..            ...      ...        ...
# 559           백양산        2          4
# 560          송도반도        1          0
# 562           이기대        1          0
# 563            장산        4          3
# 565         학리방파제        4          3
#
# [453 rows x 3 columns]

# %%
# cluster_M column을 기준으로 groupby

df_groupby_cluster_M = df_mecab_verb.groupby('cluster_M').count()
df_groupby_cluster_M
# Out:
#            Unnamed: 0  keyword  mecab_adj  cluster
# cluster_M
# 0                  72       72         72       72
# 1                 143      143        143      143
# 2                  55       55         55       55
# 3                 125      125        125      125
# 4                 171      171        171      171

# %%
# cluster 4인 keyword 출력

df_mecab_verb_cluster_result[df_mecab_verb_cluster_result['cluster_M'] == 4]
# Out:
#                       keyword  cluster  cluster_M
# 1                       25의용단        0          4
# 10           SEA LIFE 부산아쿠아리움        3          4
# 11                     UN평화축제        2          4
# 12   [부산 갈맷길 2코스] 2구간 민락교~오륙도        2          4
# 15                     가덕도 등대        2          4
# ..                        ...      ...        ...
# 552                       감천항        2          4
# 554                     낙동강하구        2          4
# 556                        두도        2          4
# 557                      두송반도        0          4
# 559                       백양산        2          4
#
# [171 rows x 3 columns]

# %%
# cluster 2인 keyword를 리스트 형태로 출력

df_mecab_verb_cluster_result[df_mecab_verb_cluster_result['cluster_M'] == 2]['keyword'].tolist()
# Out:
# ['KT&G 상상마당 부산',
#  '감지해변',
#  '금강식물원',
#  '금정산성 막걸리',
#  '금정산성축제',
#  '기장붕장어축제',
#  '내원정사(부산)',
#  '당산',
#  '대신공원',
#  '대천공원',
#  '동래온천(허심청)',
#  '라라라페스티벌',
#  '만들숲',
#  '모루식당',
#  '모모스로스터리&커피바',
#  '미포항',
#  '민락수변공원',
#  '범어사 템플스테이',
#  '법륜사(부산)',
#  '부산 암남공원',
#  '부산 에덴공원',
#  '부산 영화의 전당',
#  '부산아이스링크',
#  '부산자갈치축제',
#  '부산자유회관(부산통일관)',
#  '부산푸드필름페스타',
#  '비비비당',
#  '사상강변축제',
#  '삼진어묵체험·역사관',
#  '소름요',
#  '송상현광장',
#  '송정집',
#  '신세계 센텀시티',
#  '에테르',
#  '영도마리나오토캠핑장',
#  '영도커피페스티벌',
#  '이동항',
#  '이중섭거리',
#  '일광해수욕장',
#  '장안사계곡',
#  '전포커피축제',
#  '정인갤러리',
#  '지오클럽',
#  '차이나타운특구 문화축제',
#  '초량교회',
#  '카운트다운&해맞이축제',
#  '커피어웨이크',
#  '코하루',
#  '태종대온천찜질방',
#  '피아크',
#  '해리단길',
#  '해운대달맞이온천축제',
#  '해운대북극곰축제',
#  '해운대온천센터',
#  '헤이든']

# %% [markdown]
# # 전체 시각화 및 분석

# %%
# 시각화 하되 keyword의 이름을 표시하고 각 keyword의 kmeans.labels_ 와 kmedoids.labels_의 cluster 숫자를 점 옆에 표시
# 점 크기와 글씨 크기 작게 설정

import matplotlib.pyplot as plt

from sklearn.decomposition import PCA

plt.figure(figsize=(100, 100))

pca = PCA(n_components=2)

pca.fit(tfidf_matrix.toarray())

pca_data = pca.transform(tfidf_matrix.toarray())

plt.scatter(pca_data[:, 0], pca_data[:, 1], c=kmedoids.labels_, alpha=0.5)

for i in range(len(pca_data[:, 0])):
    plt.text(pca_data[i, 0], pca_data[i, 1], df_mecab_verb['keyword'][i] + ' ' + str(kmeans.labels_[i]) + ' ' + str(kmedoids.labels_[i]))




plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 233 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 65279 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 233 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 65279 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.savefig('cluster.png')

# %%
# tfidf_matrix를 keyword와 함께 df_mecab_verb_matrix에 저장
vectorizer = TfidfVectorizer()

df_mecab_verb_matrix = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names())
df_mecab_verb_matrix['keyword'] = df_mecab_verb['keyword']
df_mecab_verb_matrix.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-17-53005f7a9ef4> in <module>
#       2 vectorizer = TfidfVectorizer()
#       3
# ----> 4 df_mecab_adj_matrix = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names())
#       5 df_mecab_adj_matrix['keyword'] = df_mecab_adj['keyword']
#       6 df_mecab_adj_matrix.head()
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py in wrapped(*args, **kwargs)
#      86         def wrapped(*args, **kwargs):
#      87             warnings.warn(msg, category=FutureWarning)
# ...

# %%
# df_mecab_verb_matrix를 csv로 저장
df_mecab_verb_matrix.to_csv('df_mecab_verb_matrix.csv')
