# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Code\현국\noun_cluster_result.csv 불러오기

import pandas as pd

df_noun_c = pd.read_csv('/content/drive/My Drive/Code/현국/noun_cluster_result.csv', encoding='utf-8', index_col=0)
df_noun_c.head()
# Out:
#             keyword                                               noun  \
# 0             168계단  카페 뷰 친절 아빠 해변 조형물 놀이 휴식 운전 전망 문화 터미널 돼지 건물 음료 ...
# 1          40계단 문화관  카페 뷰 계절 음악 힐링 친절 아빠 여름 순대 해변 조형물 놀이 휴식 운전 전망 문...
# 2     40계단 문화관광테마거리  카페 뷰 음악 힐링 친절 아빠 입장료 순대 해변 조형물 시장 휴식 운전 전망 문화 ...
# 3             AREA6  카페 아빠 순대 운전 돼지 불편 입구 부산역 유명 전망대 해산물 새우 박물관 산 등...
# 4  SEA LIFE 부산아쿠아리움  카페 뷰 계절 힐링 동물 친절 아빠 입장료 순대 해변 휴식 놀이 문화 건물 카 입구...
#
#    cluster
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
# /content/drive/MyDrive/Data/df_mecab_adj.csv 불러오기

df_adj = pd.read_csv('/content/drive/MyDrive/Data/df_mecab_adj.csv', encoding='utf-8', index_col=0)

df_adj.head()
# Out:
#          keyword                                          mecab_adj
# 0          168계단  ['있', '없', '있', '없', '비싸', '멀', '있', '많', '있',...
# 1          25의용단  ['좋', '없', '없', '없', '없', '같', '있', '있', '어렵',...
# 2       40계단 문화관  ['늦', '좋', '좋', '없', '같', '비싸', '좋', '크', '크',...
# 3  40계단 문화관광테마거리  ['수많', '있', '없', '없', '없', '있', '깊', '있', '있',...
# 4     60년전통 할매국밥  ['맛있', '없', '싫', '없', '맛있', '좋', '맛있', '아쉬우', ...

# %%
# df_noun_c에 mecab_adj 컬럼 추가

df_noun_c['mecab_adj'] = ''
df_noun_c.head()
# Out:
#             keyword                                               noun  \
# 0             168계단  카페 뷰 친절 아빠 해변 조형물 놀이 휴식 운전 전망 문화 터미널 돼지 건물 음료 ...
# 1          40계단 문화관  카페 뷰 계절 음악 힐링 친절 아빠 여름 순대 해변 조형물 놀이 휴식 운전 전망 문...
# 2     40계단 문화관광테마거리  카페 뷰 음악 힐링 친절 아빠 입장료 순대 해변 조형물 시장 휴식 운전 전망 문화 ...
# 3             AREA6  카페 아빠 순대 운전 돼지 불편 입구 부산역 유명 전망대 해산물 새우 박물관 산 등...
# 4  SEA LIFE 부산아쿠아리움  카페 뷰 계절 힐링 동물 친절 아빠 입장료 순대 해변 휴식 놀이 문화 건물 카 입구...
#
#    cluster mecab_adj
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# for i, x in enumerate(df_adj['mecab_adj']):
#     basket = []
#     for y in x :
#         if y in noun_list:
#             basket.append(y)
#     df_mecab_noun['isinTrue'].iloc[i] = basket

# %%
# df_noun_c의 keyword가 df_adj의 keyword에 포함되는 행의 mecab_adj를 df_noun_c의 mecab_adj에 추가

for i in range(len(df_noun_c)):
    for j in range(len(df_adj)):
        if df_noun_c['keyword'][i] in df_adj['keyword'][j]:
          df_noun_c['mecab_adj'][i] = df_adj['mecab_adj'][j]

df_noun_c.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             keyword                                               noun  \
# 0             168계단  카페 뷰 친절 아빠 해변 조형물 놀이 휴식 운전 전망 문화 터미널 돼지 건물 음료 ...
# 1          40계단 문화관  카페 뷰 계절 음악 힐링 친절 아빠 여름 순대 해변 조형물 놀이 휴식 운전 전망 문...
# 2     40계단 문화관광테마거리  카페 뷰 음악 힐링 친절 아빠 입장료 순대 해변 조형물 시장 휴식 운전 전망 문화 ...
# 3             AREA6  카페 아빠 순대 운전 돼지 불편 입구 부산역 유명 전망대 해산물 새우 박물관 산 등...
# 4  SEA LIFE 부산아쿠아리움  카페 뷰 계절 힐링 동물 친절 아빠 입장료 순대 해변 휴식 놀이 문화 건물 카 입구...
#
#    cluster                                          mecab_adj
# 0        0  ['있', '없', '있', '없', '비싸', '멀', '있', '많', '있',...
# 1        0  ['수많', '있', '없', '없', '없', '있', '깊', '있', '있',...
# 2        0  ['수많', '있', '없', '없', '없', '있', '깊', '있', '있',...
# ...

# %%
# [, ], ' 제거

df_noun_c['mecab_adj'] = df_noun_c['mecab_adj'].str.replace('[', '')
df_noun_c['mecab_adj'] = df_noun_c['mecab_adj'].str.replace(']', '')
df_noun_c['mecab_adj'] = df_noun_c['mecab_adj'].str.replace("'", '')
df_noun_c['mecab_adj'] = df_noun_c['mecab_adj'].str.replace(",", '')
df_noun_c.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   after removing the cwd from sys.path.
#             keyword                                               noun  \
# 0             168계단  카페 뷰 친절 아빠 해변 조형물 놀이 휴식 운전 전망 문화 터미널 돼지 건물 음료 ...
# 1          40계단 문화관  카페 뷰 계절 음악 힐링 친절 아빠 여름 순대 해변 조형물 놀이 휴식 운전 전망 문...
# 2     40계단 문화관광테마거리  카페 뷰 음악 힐링 친절 아빠 입장료 순대 해변 조형물 시장 휴식 운전 전망 문화 ...
# ...

# %%
# df_noun_c 저장

df_noun_c.to_csv('/content/drive/My Drive/Code/현국/noun_cluster_result.csv', encoding='utf-8')

# %%
# 각 keyword의 cluster가 0이라면 별도의 csv로 저장

df_noun_c[df_noun_c['cluster'] == 0].to_csv('/content/drive/My Drive/Code/현국/noun_cluster_result_0.csv', encoding='utf-8-sig', index=False)

# cluster 1에서 4도 동일하게 진행

df_noun_c[df_noun_c['cluster'] == 1].to_csv('/content/drive/My Drive/Code/현국/noun_cluster_result_1.csv', encoding='utf-8-sig', index=False)
df_noun_c[df_noun_c['cluster'] == 2].to_csv('/content/drive/My Drive/Code/현국/noun_cluster_result_2.csv', encoding='utf-8-sig', index=False)
df_noun_c[df_noun_c['cluster'] == 3].to_csv('/content/drive/My Drive/Code/현국/noun_cluster_result_3.csv', encoding='utf-8-sig', index=False)
df_noun_c[df_noun_c['cluster'] == 4].to_csv('/content/drive/My Drive/Code/현국/noun_cluster_result_4.csv', encoding='utf-8-sig', index=False)

# 0 클러스터 헤드

df_noun_c[df_noun_c['cluster'] == 0].head()
# Out:
#             keyword                                               noun  \
# 0             168계단  카페 뷰 친절 아빠 해변 조형물 놀이 휴식 운전 전망 문화 터미널 돼지 건물 음료 ...
# 1          40계단 문화관  카페 뷰 계절 음악 힐링 친절 아빠 여름 순대 해변 조형물 놀이 휴식 운전 전망 문...
# 2     40계단 문화관광테마거리  카페 뷰 음악 힐링 친절 아빠 입장료 순대 해변 조형물 시장 휴식 운전 전망 문화 ...
# 3             AREA6  카페 아빠 순대 운전 돼지 불편 입구 부산역 유명 전망대 해산물 새우 박물관 산 등...
# 4  SEA LIFE 부산아쿠아리움  카페 뷰 계절 힐링 동물 친절 아빠 입장료 순대 해변 휴식 놀이 문화 건물 카 입구...
#
#    cluster                                          mecab_adj
# 0        0  있 없 있 없 비싸 멀 있 많 있 있 있 있 많 많 무섭 힘들 좋 있 많 다르 귀엽...
# 1        0  수많 있 없 없 없 있 깊 있 있 좋 멋지 있 없 있 있 있 많 많 수많 같 없 같...
# 2        0  수많 있 없 없 없 있 깊 있 있 좋 멋지 있 없 있 있 있 많 많 수많 같 없 같...
# 3        0  짧 알차 넓 있 없 힘들 젊 그렇 짧 좋 늦 엄청나 있 있 같 낮 많 좁 많 많 없...
# 4        0  없 있 같 넓 같 같 좋 같 많 많 같 좋 좋 있 있 없 같 넓 같 크 크 나쁘 같...

# %%
# df_00 부터 04 까지 각 키워드별 가장 많이 나온 형용사 50개씩 추출

df_00 = df_noun_c[df_noun_c['cluster'] == 0]
df_01 = df_noun_c[df_noun_c['cluster'] == 1]
df_02 = df_noun_c[df_noun_c['cluster'] == 2]
df_03 = df_noun_c[df_noun_c['cluster'] == 3]
df_04 = df_noun_c[df_noun_c['cluster'] == 4]

# %%
# df_00 부터 04 까지 각 키워드별 가장 많이 나온 형용사 50개씩 추출

df_00['mecab_adj'] = df_00['mecab_adj'].str.split(' ')
df_00['mecab_adj'] = df_00['mecab_adj'].apply(lambda x: pd.Series(x).value_counts().index[:50])
df_00.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#             keyword                                               noun  \
# 0             168계단  카페 뷰 친절 아빠 해변 조형물 놀이 휴식 운전 전망 문화 터미널 돼지 건물 음료 ...
# ...

# %%
df_01['mecab_adj'] = df_01['mecab_adj'].str.split(' ')
df_01['mecab_adj'] = df_01['mecab_adj'].apply(lambda x: pd.Series(x).value_counts().index[:50])
df_01.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              keyword                                               noun  \
# 183       60년전통 할매국밥  카페 뷰 친절 여름 순대 해변 단체 시장 고급 운전 터미널 문화 돼지 건물 카 입구...
# 184          BIFF 광장  카페 뷰 힐링 친절 여름 순대 해변 단체 시장 운전 문화 건물 불편 카 입구 칼국수...
# ...

# %%
df_02['mecab_adj'] = df_02['mecab_adj'].str.split(' ')
df_02['mecab_adj'] = df_02['mecab_adj'].apply(lambda x: pd.Series(x).value_counts().index[:50])
df_02.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            keyword                                               noun  \
# 349          25의용단  카페 뷰 힐링 입장료 문화 나무 건물 불편 입구 칼국수 출구 여유 갤러리 자유 박물...
# 350         UN평화축제  카페 뷰 힐링 아빠 해변 조형물 시장 운전 전망 문화 터미널 나무 건물 입구 부산역...
# ...

# %%
df_03['mecab_adj'] = df_03['mecab_adj'].str.split(' ')
df_03['mecab_adj'] = df_03['mecab_adj'].apply(lambda x: pd.Series(x).value_counts().index[:50])
df_03.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            keyword                                               noun  \
# 467           75광장  카페 아빠 순대 운전 불편 입구 부산역 유명 낙동강 전망대 해산물 새우 박물관 곱창...
# 468   KT&G 상상마당 부산  카페 아빠 순대 공부 운전 돼지 불편 입구 부산역 유명 낙동강 전망대 해산물 새우 ...
# ...

# %%
df_04['mecab_adj'] = df_04['mecab_adj'].str.split(' ')
df_04['mecab_adj'] = df_04['mecab_adj'].apply(lambda x: pd.Series(x).value_counts().index[:50])
df_04.head()
# Out:
# Empty DataFrame
# Columns: [keyword, noun, cluster, mecab_adj]
# Index: []

# %%
# 불러온 다음 명사 형용사 사전에 있는 것만 남기기

# %%
# 벡터화

# %%
# 시각화
